# %%
import pandas as pd

df = pd.read_csv("dataset.csv")

print(f"Dimensions: {df.shape[0]} rows x {df.shape[1]} columns")
df.head(5)
# Out:
# Dimensions: 10200 rows x 10 columns
#                                  doc_id document_type  \
# 0  bdd640fb-0667-4ad1-9c80-317fa3b1799d       invoice
# 1  c33f4584-b23b-41d8-893c-d01609de8895      contract
# 2  b39cfd4b-8abe-4d78-8520-10116895cea8        report
# 3  41f60be0-7cef-4aa3-aaed-cf4a4599a084         email
# 4  0a3aee49-6666-4879-938d-da71e3658966        resume
#
#                                         visible_text  \
# 0  Invoice for consulting services.\nServices: Da...
# 1  This Service Agreement is entered into between...
# 2  Q2 2026 Key Findings:\n- Revenue increased 12%...
# 3  To: All Staff\nFrom: IT Security Department\nR...
# 4  PROFESSIONAL SUMMARY\nSenior Data Engineer wit...
#
#                                       extracted_text  \
# 0  INVOICE\nGenerated: 2026-06-17  |  ID: D26D931...
# 1  SERVICE AGREEMENT\nGenerated: 2026-06-17  |  I...
# 2  QUARTERLY ANALYSIS REPORT\nGenerated: 2026-06-...
# 3  INTERNAL MEMORANDUM\nGenerated: 2026-06-17  | ...
# ...
